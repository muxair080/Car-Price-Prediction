# %%
import pandas as pd
import numpy as np

# %%
car = pd.read_csv('Quikr_car.csv')

# %%
car.head()
# Out:
#    Unnamed: 0                                          Name     Label  \
# 0           0       Ford Figo Duratec Petrol EXI 1.2 - 2015  PLATINUM
# 1           1        Maruti Suzuki Wagon R VXI BS IV - 2016  PLATINUM
# 2           2  Hyundai Creta 1.6 SX PLUS AUTO PETROL - 2018  PLATINUM
# 3           3                          Hyundai Venue - 2019  PLATINUM
# 4           4                             Honda Jazz - 2017  PLATINUM
#
#     Location       Price   Kms_driven Fuel_type       Owner  Year  Company
# 0  Bangalore   ₹3,80,000  35,056 kms     Petrol         NaN  2015     Ford
# 1  Bangalore   ₹4,65,000  44,000 kms     Petrol         NaN  2016   Maruti
# 2  Bangalore  ₹13,50,000  42,917 kms     Petrol         NaN  2018  Hyundai
# 3    Chennai  ₹10,19,699  16,112 kms    Petrol    2nd Owner  2019  Hyundai
# 4       Pune   ₹7,13,499  30,988 kms    Petrol    2nd Owner  2017    Honda

# %%
 car.drop("Unnamed: 0", axis=1, inplace=True)

# %%
car.head()
# Out:
#                                            Name     Label   Location  \
# 0       Ford Figo Duratec Petrol EXI 1.2 - 2015  PLATINUM  Bangalore
# 1        Maruti Suzuki Wagon R VXI BS IV - 2016  PLATINUM  Bangalore
# 2  Hyundai Creta 1.6 SX PLUS AUTO PETROL - 2018  PLATINUM  Bangalore
# 3                          Hyundai Venue - 2019  PLATINUM    Chennai
# 4                             Honda Jazz - 2017  PLATINUM       Pune
#
#         Price   Kms_driven Fuel_type       Owner  Year  Company
# 0   ₹3,80,000  35,056 kms     Petrol         NaN  2015     Ford
# 1   ₹4,65,000  44,000 kms     Petrol         NaN  2016   Maruti
# 2  ₹13,50,000  42,917 kms     Petrol         NaN  2018  Hyundai
# 3  ₹10,19,699  16,112 kms    Petrol    2nd Owner  2019  Hyundai
# 4   ₹7,13,499  30,988 kms    Petrol    2nd Owner  2017    Honda

# %%
car.drop(["Label","Location","Owner"], axis=1, inplace=True)

# %%
car.head(2)
# Out:
#                                       Name      Price   Kms_driven Fuel_type  \
# 0  Ford Figo Duratec Petrol EXI 1.2 - 2015  ₹3,80,000  35,056 kms     Petrol
# 1   Maruti Suzuki Wagon R VXI BS IV - 2016  ₹4,65,000  44,000 kms     Petrol
#
#    Year Company
# 0  2015    Ford
# 1  2016  Maruti

# %%
car.shape
# Out:
# (1032, 6)

# %%
car.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1032 entries, 0 to 1031
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Name        1032 non-null   object
#  1   Price       1032 non-null   object
#  2   Kms_driven  1032 non-null   object
#  3   Fuel_type   1032 non-null   object
#  4   Year        1032 non-null   int64
#  5   Company     1032 non-null   object
# dtypes: int64(1), object(5)
# memory usage: 48.5+ KB

# %%
car['Kms_driven'].unique()
# Out:
# array(['35,056 kms ', '44,000 kms ', '42,917 kms ', '16,112 kms ',
#        '30,988 kms ', '69,163 kms ', '42,859 kms ', '34,919 kms ',
#        '44,940 kms ', '13,687 kms ', '29,848 kms ', '21,426 kms ',
#        '68,177 kms ', '70,650 kms ', '25,730 kms ', '47,096 kms ',
#        '1,31,000 kms ', '26,000 kms ', '58,460 kms ', '48,000 kms ',
#        '26,600 kms ', '36,000 kms ', '39,500 kms ', '76,000 kms ',
#        '23,698 kms ', '37,860 kms ', '91,830 kms ', '31,172 kms ',
#        '3,243 kms ', '9,616 kms ', '30,249 kms ', '60,875 kms ',
#        '25,740 kms ', '38,587 kms ', '3,108 kms ', '35,353 kms ',
#        '34,748 kms ', '2,359 kms ', '17,814 kms ', '68,934 kms ',
#        '72,600 kms ', '81,000 kms ', '80,000 kms ', '12,000 kms ',
#        '6,000 kms ', '56,000 kms ', '15,840 kms ', '32,482 kms ',
#        '1,13,779 kms ', '26,150 kms ', '34,555 kms ', '30,880 kms ',
#        '70,423 kms ', '30,232 kms ', '50,077 kms ', '18,482 kms ',
# ...

# %% [markdown]
# # Quality
#     1)Year Column is ok
#     2)Year is in int ok
#     3) prie convert to int and remove the symbol
#     4) kms to int and remove the kms from each value
#     5) remove nan value from kms_driven
#     6) fule type has some nan values remove it
#     7) Keep first 3 words of name

# %% [markdown]
# # Cleaning

# %%
# store backup of the data
backup = car.copy()

# %%
car['Year']
# Out:
# 0       2015
# 1       2016
# 2       2018
# 3       2019
# 4       2017
#         ...
# 1027    2014
# 1028    2014
# 1029    2017
# 1030    2017
# 1031    2017
# Name: Year, Length: 1032, dtype: int64

# %%
# car['Price'] = str(car['Price'])

# %%
car.head(5)
# Out:
#                                            Name       Price   Kms_driven  \
# 0       Ford Figo Duratec Petrol EXI 1.2 - 2015   ₹3,80,000  35,056 kms
# 1        Maruti Suzuki Wagon R VXI BS IV - 2016   ₹4,65,000  44,000 kms
# 2  Hyundai Creta 1.6 SX PLUS AUTO PETROL - 2018  ₹13,50,000  42,917 kms
# 3                          Hyundai Venue - 2019  ₹10,19,699  16,112 kms
# 4                             Honda Jazz - 2017   ₹7,13,499  30,988 kms
#
#   Fuel_type  Year  Company
# 0    Petrol  2015     Ford
# 1    Petrol  2016   Maruti
# 2    Petrol  2018  Hyundai
# 3   Petrol   2019  Hyundai
# 4   Petrol   2017    Honda

# %%
car['Price'] = car['Price'].str.replace('₹',"")

# %%
car = car[car['Price'] != 'Ask For Price']

# %%
car[car['Price'].str.isnumeric()]
# Out:
# Empty DataFrame
# Columns: [Name, Price, Kms_driven, Fuel_type, Year, Company]
# Index: []

# %%
car['Price'] = car['Price'].str.replace(',',"").astype(int)

# %%
car['Price']
# Out:
# 0        380000
# 1        465000
# 2       1350000
# 3       1019699
# 4        713499
#          ...
# 1027     229000
# 1028     275000
# 1029    1750000
# 1030    1750000
# 1031    1750000
# Name: Price, Length: 1026, dtype: int32

# %%
# remove the kms and , from each value of kms_driven 
# car['Kms_driven'] = car['Kms_driven'].str.split(' ').str.get(0).str.replace(',','')
car['Kms_driven']=car['Kms_driven'].str.split().str.get(0).str.replace(',','')

# %%
car[car['Kms_driven'].str.isnumeric()]
# Out:
#                                               Name    Price Kms_driven  \
# 0          Ford Figo Duratec Petrol EXI 1.2 - 2015   380000      35056
# 1           Maruti Suzuki Wagon R VXI BS IV - 2016   465000      44000
# 2     Hyundai Creta 1.6 SX PLUS AUTO PETROL - 2018  1350000      42917
# 3                             Hyundai Venue - 2019  1019699      16112
# 4                                Honda Jazz - 2017   713499      30988
# ...                                            ...      ...        ...
# 1027                  Hyundai i10 Magna 1.2 - 2014   229000      65000
# 1028         Maruti Suzuki Alto K10 LXi CNG - 2014   275000      60000
# 1029        Jeep Compass Limited 2.0 Diesel - 2017  1750000      31000
# 1030        Jeep Compass Limited 2.0 Diesel - 2017  1750000      31000
# 1031        Jeep Compass Limited 2.0 Diesel - 2017  1750000      31000
#
#      Fuel_type  Year  Company
# 0       Petrol  2015     Ford
# 1       Petrol  2016   Maruti
# ...

# %%
# keep only numeric values of kms_driven
car = car[car['Kms_driven'].str.isnumeric()]

# %%
# convert kms_driven col to int
car['Kms_driven'] = car['Kms_driven'].astype(int)

# %%
car.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1026 entries, 0 to 1031
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Name        1026 non-null   object
#  1   Price       1026 non-null   int32
#  2   Kms_driven  1026 non-null   int32
#  3   Fuel_type   1026 non-null   object
#  4   Year        1026 non-null   int64
#  5   Company     1026 non-null   object
# dtypes: int32(2), int64(1), object(3)
# memory usage: 48.1+ KB

# %%
# remove the NAN values of Fuel_type rows from data
car = car[~car['Fuel_type'].isna()]

# %%
# Get Only First 3 words of name
car['Name'] = car['Name'].str.split(' ').str.slice(0,3).str.join(' ')

# %%
car  = car.reset_index(drop=True)

# %%
car
# Out:
#                       Name    Price  Kms_driven Fuel_type  Year  Company
# 0        Ford Figo Duratec   380000       35056    Petrol  2015     Ford
# 1      Maruti Suzuki Wagon   465000       44000    Petrol  2016   Maruti
# 2        Hyundai Creta 1.6  1350000       42917    Petrol  2018  Hyundai
# 3          Hyundai Venue -  1019699       16112   Petrol   2019  Hyundai
# 4             Honda Jazz -   713499       30988   Petrol   2017    Honda
# ...                    ...      ...         ...       ...   ...      ...
# 1021     Hyundai i10 Magna   229000       65000   Petrol   2014  Hyundai
# 1022    Maruti Suzuki Alto   275000       60000    Petrol  2014   Maruti
# 1023  Jeep Compass Limited  1750000       31000   Diesel   2017     Jeep
# 1024  Jeep Compass Limited  1750000       31000   Diesel   2017     Jeep
# 1025  Jeep Compass Limited  1750000       31000   Diesel   2017     Jeep
#
# [1026 rows x 6 columns]

# %%
# Remove outliers 
car = car[car['Price'] < 7500000].reset_index(drop=True)

# %%
car.shape
# Out:
# (1025, 6)

# %%
# Save the cleaned data in csv file
car.to_csv('Cleaned_Car.csv')

# %% [markdown]
# # Model

# %%
# Features
X = car.drop(columns='Price')
y = car['Price']

# %%
X.head()
# Out:
#                   Name  Kms_driven Fuel_type  Year  Company
# 0    Ford Figo Duratec       35056    Petrol  2015     Ford
# 1  Maruti Suzuki Wagon       44000    Petrol  2016   Maruti
# 2    Hyundai Creta 1.6       42917    Petrol  2018  Hyundai
# 3      Hyundai Venue -       16112   Petrol   2019  Hyundai
# 4         Honda Jazz -       30988   Petrol   2017    Honda

# %%
y.head()
# Out:
# 0     380000
# 1     465000
# 2    1350000
# 3    1019699
# 4     713499
# Name: Price, dtype: int32

# %%
from sklearn.model_selection import train_test_split
X_train,X_test, y_train,y_test = train_test_split(X,y, test_size=.2, random_state=42)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import make_column_transformer
from sklearn.pipeline import make_pipeline

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1025 entries, 0 to 1024
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Name        1025 non-null   object
#  1   Kms_driven  1025 non-null   int32
#  2   Fuel_type   1025 non-null   object
#  3   Year        1025 non-null   int64
#  4   Company     1025 non-null   object
# dtypes: int32(1), int64(1), object(3)
# memory usage: 36.2+ KB

# %%
ohe = OneHotEncoder()
ohe.fit(X[['Name','Company','Fuel_type']])
# Out:
# OneHotEncoder()

# %%
# column_trans = make_column_transformer((OneHotEncoder(categories=ohe.categories_)
# ,['Name','Company','Fuel_type']), remainder='passthrough')
column_trans=make_column_transformer((OneHotEncoder(handle_unknown='ignore', categories=ohe.categories_),['Name','Company','Fuel_type']),
                                    remainder='passthrough')

# %%
lr = LinearRegression()

# %%
pipe = make_pipeline(column_trans, lr)

# %%
pipe.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('onehotencoder',
#                                                   OneHotEncoder(categories=[array(['Audi Q3 -', 'Audi Q5 2.0', 'Audi Q7 3.0', 'Audi Q7 35',
#        'BMW 3 Series', 'BMW 5 Series', 'BMW X5 xDrive30d',
#        'Chevrolet Aveo -', 'Chevrolet Beat -', 'Chevrolet Beat LS',
#        'Chevrolet Beat LT', 'Chevrolet Cruze LTZ', 'Chevrolet Optra -',
#        'Chevrolet S...
#        'Hyundai', 'Jaguar', 'Jeep', 'Kia', 'Land', 'MG', 'Mahindra',
#        'Maruti', 'Mercedes', 'Nissan', 'Porsche', 'Renault', 'Skoda',
#        'Ssangyong', 'Tata', 'Toyota', 'Volkswagen', 'Volvo'], dtype=object),
#                                                                             array([' CNG', ' CNG ', ' Diesel', ' Diesel ', ' Electric ', ' Hybrid ',
#        ' LPG', ' Petrol', ' Petrol ', ' Petrol + CNG '], dtype=object)],
# ...

# %%
pred = pipe.predict(X_test)

# %%
r2_score(y_test,pred)
# Out:
# 0.5264850846003879

# %%
scores = []
for i in range(1000):
    X_train,X_test, y_train,y_test = train_test_split(X,y, test_size=.2, random_state=i)
    lr = LinearRegression()
    pipe = make_pipeline(column_trans, lr)
    pipe.fit(X_train, y_train)
    pred = pipe.predict(X_test)
    scores.append(r2_score(y_test,pred))

# %%
scores
# Out:
# [0.6657941165508021,
#  0.6573994132296335,
#  0.4728607895451731,
#  0.6766820062536268,
#  0.5225051934568805,
#  0.643363815840117,
#  0.6028382441483784,
#  0.6677140929311864,
#  0.7527707833630377,
#  0.561873892783898,
#  0.49946597472054544,
#  0.5631525639127193,
#  0.6992902747946189,
#  0.7758632280926726,
#  0.7997009876046691,
#  0.7232736996130165,
#  0.8162817421921209,
#  0.5547640522333369,
#  0.8108019062546635,
#  0.7126441725950355,
#  0.6002419037813127,
#  0.6733141589819869,
#  0.6763826918742992,
#  0.6965627518765163,
#  0.6386052950989278,
#  0.592145092107863,
#  0.5783436360454322,
#  0.705481608281049,
#  0.468794811970337,
#  0.677780099325943,
#  0.6292083233440564,
#  0.5256802964588216,
#  0.6947807550408811,
#  0.7455857168277189,
#  0.6150254511104676,
#  0.6389481731859341,
#  0.7391541557612565,
#  0.5953122639529238,
#  0.6973985862676575,
#  0.7316577408916861,
#  0.6430124775580583,
#  0.5033589256992963,
#  0.5264850846003879,
# ...

# %%
np.argmax(scores)
# Out:
# 548

# %%
scores[np.argmax(scores)]
# Out:
# 0.8679320376640818

# %%
X_train,X_test, y_train,y_test = train_test_split(X,y, test_size=.2, random_state=np.argmax(scores))
lr = LinearRegression()
pipe = make_pipeline(column_trans, lr)
pipe.fit(X_train, y_train)
pred = pipe.predict(X_test)
r2_score(y_test, pred)
# Out:
# 0.8679320376640818

# %%
import pickle
pickle.dump(pipe, open('LinearRegressionModel.pkl','wb'))

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1025 entries, 0 to 1024
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Name        1025 non-null   object
#  1   Kms_driven  1025 non-null   int32
#  2   Fuel_type   1025 non-null   object
#  3   Year        1025 non-null   int64
#  4   Company     1025 non-null   object
# dtypes: int32(1), int64(1), object(3)
# memory usage: 36.2+ KB

# %%
pipe.predict(pd.DataFrame([['Maruti Suzuki Swift','Maruti',2019,100,'Petrol']], columns=['Name','Company','Year','Kms_driven','Fuel_type']))
# Out:
# array([803747.85462829])
